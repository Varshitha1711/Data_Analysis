# %% [markdown]
# ### loan_approved.csv

# %%
import pandas as pd

# %%
df=pd.read_csv("loan_approved.csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)
# 0             1.0         Urban                      Y
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Loan_ID                 614 non-null    object
#  1   Gender                  601 non-null    object
#  2   Married                 611 non-null    object
#  3   Dependents              599 non-null    object
#  4   Education               614 non-null    object
#  5   Self_Employed           582 non-null    object
#  6   ApplicantIncome         614 non-null    int64
#  7   CoapplicantIncome       614 non-null    float64
#  8   LoanAmount              592 non-null    float64
#  9   Loan_Amount_Term        600 non-null    float64
#  10  Credit_History          564 non-null    float64
#  11  Property_Area           614 non-null    object
#  12  Loan_Status (Approved)  614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area',
#        'Loan_Status (Approved)'],
#       dtype='object')

# %%
len(df["Loan_ID"].unique())
# Out:
# 614

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df["Married"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df["Dependents"].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df["Education"].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df["Self_Employed"].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df["ApplicantIncome"].unique()
# Out:
# array([ 5849,  4583,  3000,  2583,  6000,  5417,  2333,  3036,  4006,
#        12841,  3200,  2500,  3073,  1853,  1299,  4950,  3596,  3510,
#         4887,  2600,  7660,  5955,  3365,  3717,  9560,  2799,  4226,
#         1442,  3750,  4166,  3167,  4692,  3500, 12500,  2275,  1828,
#         3667,  3748,  3600,  1800,  2400,  3941,  4695,  3410,  5649,
#         5821,  2645,  4000,  1928,  3086,  4230,  4616, 11500,  2708,
#         2132,  3366,  8080,  3357,  3029,  2609,  4945,  5726, 10750,
#         7100,  4300,  3208,  1875,  4755,  5266,  1000,  3333,  3846,
#         2395,  1378,  3988,  2366,  8566,  5695,  2958,  6250,  3273,
#         4133,  3620,  6782,  2484,  1977,  4188,  1759,  4288,  4843,
#        13650,  4652,  3816,  3052, 11417,  7333,  3800,  2071,  5316,
#         2929,  3572,  7451,  5050, 14583,  2214,  5568, 10408,  5667,
#         2137,  2957,  3692, 23803,  3865, 10513,  6080, 20166,  2014,
# ...

# %%
len(df["CoapplicantIncome"].unique())
# Out:
# 287

# %%
df["LoanAmount"].unique()
# Out:
# array([ nan, 128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70.,
#        109., 200., 114.,  17., 125., 100.,  76., 133., 115., 104., 315.,
#        116., 112., 151., 191., 122., 110.,  35., 201.,  74., 106., 320.,
#        144., 184.,  80.,  47.,  75., 134.,  96.,  88.,  44., 286.,  97.,
#        135., 180.,  99., 165., 258., 126., 312., 136., 172.,  81., 187.,
#        113., 176., 130., 111., 167., 265.,  50., 210., 175., 131., 188.,
#         25., 137., 160., 225., 216.,  94., 139., 152., 118., 185., 154.,
#         85., 259., 194.,  93., 370., 182., 650., 102., 290.,  84., 242.,
#        129.,  30., 244., 600., 255.,  98., 275., 121.,  63., 700.,  87.,
#        101., 495.,  67.,  73., 260., 108.,  58.,  48., 164., 170.,  83.,
#         90., 166., 124.,  55.,  59., 127., 214., 240.,  72.,  60., 138.,
#         42., 280., 140., 155., 123., 279., 192., 304., 330., 150., 207.,
#        436.,  78.,  54.,  89., 143., 105., 132., 480.,  56., 159., 300.,
# ...

# %%
df["Loan_Amount_Term"].unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
df["Credit_History"].unique()
# Out:
# array([ 1.,  0., nan])

# %%
df["Property_Area"].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
df["Loan_Status (Approved)"].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %% [markdown]
# ### Feature datatypes
#
# 1. Loan_ID   -Categorical
# 2. Gender   -Categorical-nominal
# 3. Married   -Categorical-nominal
# 4. Dependents   -Categorical-ordinal
# 5. Education   -Categorical-nominal
# 6. Self-employed   -Categorical-nominal
# 7. ApplicantIncome   - Numerical-continuous
# 8. CoapplicantIncome   -Numerical -continuous
# 9. LoanAmount    -Numerical -continuous
# 10. Loan_Amount_Term    -Numerical-discrete
# 11. Credit_history     -Categorical -nominal
# 12. Property_Area     -Categorical -ordinal
# 13. Loan_status     -Categorical -nominal

# %%
import numpy as np
print(df["LoanAmount"].isnull().sum())
df["LoanAmount"].fillna(df["LoanAmount"].mean(),inplace=True)
print(df["LoanAmount"].isnull().sum())
# Out:
# 22
# 0
# C:\Users\91934\AppData\Local\Temp\ipykernel_15488\2106501626.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["LoanAmount"].fillna(df["LoanAmount"].mean(),inplace=True)

# %%
print(df["Loan_Amount_Term"].isnull().sum())
df["Loan_Amount_Term"].fillna(df["Loan_Amount_Term"].median(),inplace=True)
print(df["Loan_Amount_Term"].isnull().sum())
# Out:
# 14
# 0
# C:\Users\91934\AppData\Local\Temp\ipykernel_15488\3692432365.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Loan_Amount_Term"].fillna(df["Loan_Amount_Term"].median(),inplace=True)

# %%
import seaborn as sns
sns.countplot(x='Dependents', hue='Loan_Status (Approved)', data=df)
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
sns.countplot(x='Education', hue='Loan_Status (Approved)', data=df)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.countplot(x='Gender', hue='Loan_Status (Approved)', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Married', hue='Loan_Status (Approved)', data=df)
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
df.Credit_History.value_counts()
# Out:
# Credit_History
# 1.0    475
# 0.0     89
# Name: count, dtype: int64

# %%
df.ApplicantIncome.mean()
# Out:
# np.float64(5403.459283387622)

# %%
df.ApplicantIncome.std()
# Out:
# 6109.041673387174

# %%
m=df.ApplicantIncome.mean()
s=df.ApplicantIncome.std()
data=df['ApplicantIncome'].head()
z=list()
for i in data:
    z.append((i-m)/s)
print(z)
# Out:
# [np.float64(0.07293135984867927), np.float64(-0.13430245319192863), np.float64(-0.3934265653904138), np.float64(-0.4616860440933629), np.float64(0.09764882096173755)]

# %%
ran=df['ApplicantIncome'].max()-df['ApplicantIncome'].min()
print(ran)
# Out:
# 80850

# %%
sns.boxplot(data=df,x='ApplicantIncome')
# Out:
# <Axes: xlabel='ApplicantIncome'>

# %%
print("Skewness of Applicant Income:",df.ApplicantIncome.skew())
print("Skewness of Coapplicant Income:",df.CoapplicantIncome.skew())
print("Skewness of Loan Amount:",df.LoanAmount.skew())
print("Skewness of Loan Amount term:",df.Loan_Amount_Term.skew())
# Out:
# Skewness of Applicant Income: 6.539513113994625
# Skewness of Coapplicant Income: 7.491531216657306
# Skewness of Loan Amount: 2.726601144105299
# Skewness of Loan Amount term: -2.4021122563890396

# %%
print("Kurtosis of Applicant Income:",df.ApplicantIncome.kurtosis())
print("Kurtosis of Copplicant Income:",df.CoapplicantIncome.kurtosis())
print("Kurtosis of Loan amount:",df.LoanAmount.kurtosis())
print("Kurtosis of Loan_Amount_Term:",df.Loan_Amount_Term.kurtosis())
# Out:
# Kurtosis of Applicant Income: 60.54067593369113
# Kurtosis of Copplicant Income: 84.95638421103374
# Kurtosis of Loan amount: 10.896456468091559
# Kurtosis of Loan_Amount_Term: 6.924993328965206

# %%
print("Applicant income is highly right skewed")
sns.histplot(data=df,x="ApplicantIncome")
# Out:
# Applicant income is highly right skewed
# <Axes: xlabel='ApplicantIncome', ylabel='Count'>

# %%
print("Coapplicant income is highly right skewed")
sns.histplot(data=df,x="CoapplicantIncome",kde=True)
# Out:
# Coapplicant income is highly right skewed
# <Axes: xlabel='CoapplicantIncome', ylabel='Count'>

# %%
print("loan amount is highly right skewed")
sns.histplot(data=df,x="LoanAmount")
# Out:
# loan amount is highly right skewed
# <Axes: xlabel='LoanAmount', ylabel='Count'>

# %%
print("Loan amount term is highly left skewed")
sns.histplot(data=df,x="Loan_Amount_Term")
# Out:
# Loan amount term is highly left skewed
# <Axes: xlabel='Loan_Amount_Term', ylabel='Count'>

# %%
df['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
df1=pd.get_dummies(df['Property_Area'],prefix="PA",dtype=int,drop_first=True)
df1
# Out:
#      PA_Semiurban  PA_Urban
# 0               0         1
# 1               0         0
# 2               0         1
# 3               0         1
# 4               0         1
# ..            ...       ...
# 609             0         0
# 610             0         0
# 611             0         1
# 612             0         1
# 613             1         0
#
# [614 rows x 2 columns]

# %%
df=pd.concat([df,df1],axis=1).drop(['Property_Area'],axis=1)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df["Married"] = df["Married"].fillna(df["Married"].mode()[0])
df.isnull().sum()
# Out:
# Loan_ID                    0
# Gender                    13
# Married                    0
# Dependents                15
# Education                  0
# Self_Employed             32
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                 0
# Loan_Amount_Term           0
# Credit_History            50
# Loan_Status (Approved)     0
# PA_Semiurban               0
# PA_Urban                   0
# dtype: int64

# %%
df["Gender"]=df["Gender"].fillna(df["Gender"].mode()[0])
df.isnull().sum()
# Out:
# Loan_ID                    0
# Gender                     0
# Married                    0
# Dependents                15
# Education                  0
# Self_Employed             32
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                 0
# Loan_Amount_Term           0
# Credit_History            50
# Loan_Status (Approved)     0
# PA_Semiurban               0
# PA_Urban                   0
# dtype: int64

# %%
df["Credit_History"]=df["Credit_History"].fillna(df["Credit_History"].mode()[0])
df.isnull().sum()
# Out:
# Loan_ID                    0
# Gender                     0
# Married                    0
# Dependents                15
# Education                  0
# Self_Employed             32
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                 0
# Loan_Amount_Term           0
# Credit_History             0
# Loan_Status (Approved)     0
# PA_Semiurban               0
# PA_Urban                   0
# dtype: int64

# %%
df["Dependents"]=df["Dependents"].fillna(df["Dependents"].mode()[0])
df.isnull().sum()
# Out:
# Loan_ID                    0
# Gender                     0
# Married                    0
# Dependents                 0
# Education                  0
# Self_Employed             32
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                 0
# Loan_Amount_Term           0
# Credit_History             0
# Loan_Status (Approved)     0
# PA_Semiurban               0
# PA_Urban                   0
# dtype: int64

# %%
df["Self_Employed"]=df["Self_Employed"].fillna(df["Self_Employed"].mode()[0])
df.isnull().sum()
# Out:
# Loan_ID                   0
# Gender                    0
# Married                   0
# Dependents                0
# Education                 0
# Self_Employed             0
# ApplicantIncome           0
# CoapplicantIncome         0
# LoanAmount                0
# Loan_Amount_Term          0
# Credit_History            0
# Loan_Status (Approved)    0
# PA_Semiurban              0
# PA_Urban                  0
# dtype: int64

# %%
df1=pd.get_dummies(df['Gender'],prefix="G",dtype=int,drop_first=True)
df1
# Out:
#      G_Male
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 609       0
# 610       1
# 611       1
# 612       1
# 613       0
#
# [614 rows x 1 columns]

# %%
df=pd.concat([df,df1],axis=1).drop(['Gender'],axis=1)
df
# Out:
#       Loan_ID Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0    LP001002      No          0      Graduate            No             5849
# 1    LP001003     Yes          1      Graduate            No             4583
# 2    LP001005     Yes          0      Graduate           Yes             3000
# 3    LP001006     Yes          0  Not Graduate            No             2583
# 4    LP001008      No          0      Graduate            No             6000
# ..        ...     ...        ...           ...           ...              ...
# 609  LP002978      No          0      Graduate            No             2900
# 610  LP002979     Yes         3+      Graduate            No             4106
# 611  LP002983     Yes          1      Graduate            No             8072
# 612  LP002984     Yes          2      Graduate            No             7583
# 613  LP002990      No          0      Graduate           Yes             4583
#
# ...

# %%
df1=pd.get_dummies(df['Credit_History'],prefix="C",dtype=int,drop_first=True)
df1
# Out:
#      C_1.0
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 609      1
# 610      1
# 611      1
# 612      1
# 613      0
#
# [614 rows x 1 columns]

# %%
df=pd.concat([df,df1],axis=1).drop(['Credit_History'],axis=1)
df
# Out:
#       Loan_ID Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0    LP001002      No          0      Graduate            No             5849
# 1    LP001003     Yes          1      Graduate            No             4583
# 2    LP001005     Yes          0      Graduate           Yes             3000
# 3    LP001006     Yes          0  Not Graduate            No             2583
# 4    LP001008      No          0      Graduate            No             6000
# ..        ...     ...        ...           ...           ...              ...
# 609  LP002978      No          0      Graduate            No             2900
# 610  LP002979     Yes         3+      Graduate            No             4106
# 611  LP002983     Yes          1      Graduate            No             8072
# 612  LP002984     Yes          2      Graduate            No             7583
# 613  LP002990      No          0      Graduate           Yes             4583
#
# ...

# %%
df1=pd.get_dummies(df['Married'],prefix="M",dtype=int,drop_first=True)
df1
# Out:
#      M_Yes
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
# ..     ...
# 609      0
# 610      1
# 611      1
# 612      1
# 613      0
#
# [614 rows x 1 columns]

# %%
df=pd.concat([df,df1],axis=1).drop(['Married'],axis=1)
df
# Out:
#       Loan_ID Dependents     Education Self_Employed  ApplicantIncome  \
# 0    LP001002          0      Graduate            No             5849
# 1    LP001003          1      Graduate            No             4583
# 2    LP001005          0      Graduate           Yes             3000
# 3    LP001006          0  Not Graduate            No             2583
# 4    LP001008          0      Graduate            No             6000
# ..        ...        ...           ...           ...              ...
# 609  LP002978          0      Graduate            No             2900
# 610  LP002979         3+      Graduate            No             4106
# 611  LP002983          1      Graduate            No             8072
# 612  LP002984          2      Graduate            No             7583
# 613  LP002990          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term Loan_Status (Approved)  \
# ...

# %%
df1=pd.get_dummies(df['Dependents'],prefix="D",dtype=int,drop_first=True)
df1
# Out:
#      D_1  D_2  D_3+
# 0      0    0     0
# 1      1    0     0
# 2      0    0     0
# 3      0    0     0
# 4      0    0     0
# ..   ...  ...   ...
# 609    0    0     0
# 610    0    0     1
# 611    1    0     0
# 612    0    1     0
# 613    0    0     0
#
# [614 rows x 3 columns]

# %%
df=pd.concat([df,df1],axis=1).drop(['Dependents'],axis=1)
df
# Out:
#       Loan_ID     Education Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 0    LP001002      Graduate            No             5849                0.0
# 1    LP001003      Graduate            No             4583             1508.0
# 2    LP001005      Graduate           Yes             3000                0.0
# 3    LP001006  Not Graduate            No             2583             2358.0
# 4    LP001008      Graduate            No             6000                0.0
# ..        ...           ...           ...              ...                ...
# 609  LP002978      Graduate            No             2900                0.0
# 610  LP002979      Graduate            No             4106                0.0
# 611  LP002983      Graduate            No             8072              240.0
# 612  LP002984      Graduate            No             7583                0.0
# 613  LP002990      Graduate           Yes             4583                0.0
#
# ...

# %%
df1=pd.get_dummies(df['Self_Employed'],prefix="S",dtype=int,drop_first=True)
df1
# Out:
#      S_Yes
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
# ..     ...
# 609      0
# 610      0
# 611      0
# 612      0
# 613      1
#
# [614 rows x 1 columns]

# %%
df=pd.concat([df,df1],axis=1).drop(['Self_Employed'],axis=1)
df
# Out:
#       Loan_ID     Education  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0    LP001002      Graduate             5849                0.0  146.412162
# 1    LP001003      Graduate             4583             1508.0  128.000000
# 2    LP001005      Graduate             3000                0.0   66.000000
# 3    LP001006  Not Graduate             2583             2358.0  120.000000
# 4    LP001008      Graduate             6000                0.0  141.000000
# ..        ...           ...              ...                ...         ...
# 609  LP002978      Graduate             2900                0.0   71.000000
# 610  LP002979      Graduate             4106                0.0   40.000000
# 611  LP002983      Graduate             8072              240.0  253.000000
# 612  LP002984      Graduate             7583                0.0  187.000000
# 613  LP002990      Graduate             4583                0.0  133.000000
#
# ...

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

sns.histplot(data=df, x="ApplicantIncome", kde=True, ax=axes[0, 0])
axes[0, 0].set_title("Applicant Income Distribution")

sns.histplot(data=df, x="CoapplicantIncome", kde=True, ax=axes[0, 1])
axes[0, 1].set_title("Coapplicant Income Distribution")

sns.histplot(data=df, x="LoanAmount", kde=True, ax=axes[1, 0])
axes[1, 0].set_title("Loan Amount Distribution")

plt.tight_layout()
plt.show()

# %%
import statsmodels.api as sm
import pylab as py

sm.qqplot(df['LoanAmount'],line='45')
py.show()

# %%
from sklearn.preprocessing import PowerTransformer
trans=PowerTransformer(method='yeo-johnson')
la_trans=trans.fit_transform(df[['LoanAmount']])
df['LoanAmount']=la_trans
la_trans.shape
# Out:
# (614, 1)

# %%
print("Skewness:",pd.Series(la_trans.reshape(614,)).skew())
print("Kurtosis:",pd.Series(la_trans.reshape(614,)).kurtosis())
# Out:
# Skewness: 0.024376135751782733
# Kurtosis: 2.3999414421592773

# %%
sns.histplot(df['LoanAmount'])
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Count'>

# %%
df['ApplicantIncome']=trans.fit_transform(df[['ApplicantIncome']])
print("Skewness of applicantincome:",df['ApplicantIncome'].skew())
print("Kurtosis:",df['ApplicantIncome'].kurtosis())
sns.histplot(df['ApplicantIncome'])
# Out:
# Skewness of applicantincome: -0.09294567889276603
# Kurtosis: 4.77062663426899
# <Axes: xlabel='ApplicantIncome', ylabel='Count'>

# %%
df['CoapplicantIncome']=trans.fit_transform(df[['CoapplicantIncome']])
print("Skewness of applicantincome:",df['CoapplicantIncome'].skew())
print("Kurtosis:",df['CoapplicantIncome'].kurtosis())
sns.histplot(df['CoapplicantIncome'])
# Out:
# Skewness of applicantincome: -0.14564645710551902
# Kurtosis: -1.8778432766544493
# <Axes: xlabel='CoapplicantIncome', ylabel='Count'>
